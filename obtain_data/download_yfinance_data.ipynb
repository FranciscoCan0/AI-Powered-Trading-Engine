# %%
import yfinance as yf
import pandas as pd
import numpy as np
from IPython.display import display
from pathlib import Path

# %%
historical_data_intervals = ["2m", "1h"]

# %%
#Import Tickers of Interest
stock_tickers = ["AAPL", "NVDA", "AMZN", #TECH
               "AXP", "BRK-B", "JPM", #BANKING
               "JNJ", "PFE", "UNH", #HEALTHCARE
               "PG", "WMT", "KO", #RETAIL
               "GE", "CAT", "LMT", #INDUSTRIAL/AEROSPACE
               "SONY", "SSNLF", "NVO",  #INTERNATIONAL
               "SPY", "VOO", "IVV", "QQQ"] #ETFs

ticker_background_data = {}

#Create dataframe of info on each stock ticker
for ticker in stock_tickers:
    ticker_object = yf.Ticker(ticker)

    #Obtain Company Data
    temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
    temp.reset_index(inplace=True)
    temp.columns = ["Attribute", "Recent"]
    ticker_background_data[ticker] = temp



#Clean backgound df information
ticker_background_data_df = pd.concat(ticker_background_data).reset_index()
ticker_background_data_df = ticker_background_data_df.drop(columns = ['level_1'])
ticker_background_data_df.columns = ["Ticker", "Attribute", "Value"]

pd.set_option("display.max_columns", None)

ticker_background_data_df
# Out:
#      Ticker         Attribute                        Value
# 0      AAPL          address1           One Apple Park Way
# 1      AAPL              city                    Cupertino
# 2      AAPL             state                           CA
# 3      AAPL               zip                        95014
# 4      AAPL           country                United States
# ...     ...               ...                          ...
# 3639    QQQ            market                    us_market
# 3640    QQQ      esgPopulated                        False
# 3641    QQQ         shortName  Invesco QQQ Trust, Series 1
# 3642    QQQ          longName            Invesco QQQ Trust
# 3643    QQQ  trailingPegRatio                         None
#
# [3644 rows x 3 columns]

# %%
trading_data_by_interval = {}


for interval in historical_data_intervals:

    ticker_trading_data = []

    for ticker in stock_tickers:

        ticker_object = yf.Ticker(ticker)

        # Obtain different granularities of trading data for different training stages
        temp = ticker_object.history(period="max", interval=interval)
        temp["Ticker"] = ticker

        if not temp.empty:
            ticker_trading_data.append(temp)

    print(f"Interval {interval} download complete.")


    trading_data_by_interval[interval] = pd.concat(ticker_trading_data)
    
for name, df in trading_data_by_interval.items():
    print(f"=== {name} ===")
    display(df)
# Out:
# Interval 1m download complete.
# Interval 2m download complete.
# Interval 1h download complete.
# === 1m ===
#                                  Open        High         Low       Close  \
# Datetime
# 2026-07-27 09:30:00-04:00  334.899994  336.700012  334.100006  335.334991
# 2026-07-27 09:31:00-04:00  335.420013  336.380005  335.119995  335.500000
# 2026-07-27 09:32:00-04:00  335.510010  336.947998  335.510010  336.739685
# 2026-07-27 09:33:00-04:00  336.700012  337.119995  336.477295  336.684998
# 2026-07-27 09:34:00-04:00  336.750000  337.040009  335.350494  335.545013
# ...                               ...         ...         ...         ...
# 2026-07-31 15:55:00-04:00  690.570007  690.599976  689.369995  689.570007
# 2026-07-31 15:56:00-04:00  689.590027  689.820007  689.530029  689.669983
# 2026-07-31 15:57:00-04:00  689.650024  689.780029  689.200012  689.200012
# 2026-07-31 15:58:00-04:00  689.229980  689.409973  689.049988  689.270020
